# %%
import pandas as pd
df = pd.read_csv("Fraud_check.csv")
df.shape
df.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
df.shape
# Out:
# (600, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    int64
#  1   Marital.Status   600 non-null    int64
#  2   Taxable.Income   600 non-null    int64
#  3   City.Population  600 non-null    int64
#  4   Work.Experience  600 non-null    int64
#  5   Urban            600 non-null    int64
# dtypes: int64(6)
# memory usage: 28.2 KB

# %%
df.describe()
# Out:
#         Undergrad  Marital.Status  Taxable.Income  City.Population  \
# count  600.000000      600.000000      600.000000       600.000000
# mean     0.520000        1.046667      299.053333       298.510000
# std      0.500017        0.821958      172.921100       172.823358
# min      0.000000        0.000000        0.000000         0.000000
# 25%      0.000000        0.000000      149.750000       148.750000
# 50%      1.000000        1.000000      299.500000       298.500000
# 75%      1.000000        2.000000      448.250000       448.250000
# max      1.000000        2.000000      598.000000       597.000000
#
#        Work.Experience       Urban
# count       600.000000  600.000000
# mean         15.558333    0.503333
# std           8.842147    0.500406
# min           0.000000    0.000000
# 25%           8.000000    0.000000
# 50%          15.000000    1.000000
# 75%          24.000000    1.000000
# max          30.000000    1.000000

# %%
# constructing histograms,calculating skewness and kurtosis values#
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,12))
df.hist()
df.skew()
df.kurt()
# Out:
# Undergrad         -2.000236
# Marital.Status    -1.514965
# Taxable.Income    -1.197175
# City.Population   -1.203540
# Work.Experience   -1.167524
# Urban             -2.006521
# dtype: float64

# %%
sns.set_style(style="darkgrid")
sns.pairplot(df)

# %%
data=["Taxable.Income","City.Population","Work.Experience"]
for column in data:
  plt.figure(figsize=(8,6))
  sns.distplot(x=df[column])
  plt.title("Distplot")
  plt.show()
# Out:
# <ipython-input-21-0576791e23eb>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[column])
# <ipython-input-21-0576791e23eb>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[column])
# <ipython-input-21-0576791e23eb>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[column])

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

# %%
for i in range(0,6):
    df.iloc[:, i] = LE.fit_transform(df.iloc[:, i])
# Out:
# <ipython-input-3-36840b4e0e38>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:, i] = LE.fit_transform(df.iloc[:, i])
# <ipython-input-3-36840b4e0e38>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:, i] = LE.fit_transform(df.iloc[:, i])
# <ipython-input-3-36840b4e0e38>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.iloc[:, i] = LE.fit_transform(df.iloc[:, i])

# %%
df.head()
# Out:
#    Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0          0               2             387               84
# 1          1               0             163              398
# 2          0               1             186              481
# 3          1               2             272              574
# 4          0               1             468                4
#
#    Work.Experience  Urban
# 0               10      1
# 1               18      1
# 2               30      1
# 3               15      1
# 4               28      0

# %%
# Data division X and Y
Y = df["Undergrad"]
X = df.iloc[:,1:6]
X.head()
# Out:
#    Marital.Status  Taxable.Income  City.Population  Work.Experience  Urban
# 0               2             387               84               10      1
# 1               0             163              398               18      1
# 2               1             186              481               30      1
# 3               2             272              574               15      1
# 4               1             468                4               28      0

# %%
# data partition
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test  = train_test_split(X,Y, test_size=0.30)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor()

DT.fit(X_train,Y_train) # Bo + b1x1 + B2x2
Y_pred_train = DT.predict(X_train)
Y_pred_test = DT.predict(X_test)
training_error = np.sqrt(mean_squared_error(Y_train,Y_pred_train)).round(3)
test_error = np.sqrt(mean_squared_error(Y_test,Y_pred_test)).round(3)

print(training_error)
print(test_error)
print("Variance: ", (test_error-training_error).round(2))
# Out:
# 0.0
# 0.749
# Variance:  0.75

# %%
DT = DecisionTreeRegressor()
from sklearn.ensemble import RandomForestRegressor
RF = RandomForestRegressor(n_estimators = 200, max_samples = 0.6, max_features=0.7,max_depth=5)

# %%
training_error = []
test_error = []
Tr = []
Ts = []

# %%
# cross validation

for i in range(1,101,1):
    X_train,X_test,Y_train,Y_test  = train_test_split(X,Y, test_size=0.30, random_state=i)
    RF.fit(X_train,Y_train)
    Y_pred_train = RF.predict(X_train)
    Y_pred_test = RF.predict(X_test)
    training_error.append(np.sqrt(mean_squared_error(Y_train,Y_pred_train)).round(3))
    test_error.append(np.sqrt(mean_squared_error(Y_test,Y_pred_test)).round(3))

import numpy as np
print("Average trianing error",np.mean(training_error).round(2))
print("Average test error",np.mean(test_error).round(2))
print("Variance: ", (np.mean(test_error)-np.mean(training_error)).round(2))
# Out:
# Average trianing error 0.44
# Average test error 0.51
# Variance:  0.07

# %%
# Gradient Boosting

from sklearn.ensemble import GradientBoostingRegressor
GBR = GradientBoostingRegressor(learning_rate=0.1,
                                n_estimators=100,
                                max_features=0.7)

# %%
training_error = []
test_error = []
Tr = []
Ts = []

# %%
# cross validation with Gradient Boosting

for i in range(1,101,1):
    X_train,X_test,Y_train,Y_test  = train_test_split(X,Y, test_size=0.30, random_state=i)
    GBR.fit(X_train,Y_train)
    Y_pred_train = GBR.predict(X_train)
    Y_pred_test = GBR.predict(X_test)
    training_error.append(np.sqrt(mean_squared_error(Y_train,Y_pred_train)).round(3))
    test_error.append(np.sqrt(mean_squared_error(Y_test,Y_pred_test)).round(3))

import numpy as np
print("Average trianing error",np.mean(training_error).round(2))
print("Average test error",np.mean(test_error).round(2))
print("Variance: ", (np.mean(test_error)-np.mean(training_error)).round(2))
# Out:
# Average trianing error 0.36
# Average test error 0.53
# Variance:  0.17

# %%
# AdaBoost Regressor

from sklearn.ensemble import AdaBoostRegressor
ABR = AdaBoostRegressor(learning_rate=0.1,
                                n_estimators=100)

# %%
training_error = []
test_error = []
Tr = []
Ts = []

# %%
# cross validation with Adaptive Boosting
import numpy as np
for i in range(1,101,1):
    X_train,X_test,Y_train,Y_test  = train_test_split(X,Y, test_size=0.30, random_state=i)
    ABR.fit(X_train,Y_train)
    Y_pred_train = ABR.predict(X_train)
    Y_pred_test = ABR.predict(X_test)
    training_error.append(np.sqrt(mean_squared_error(Y_train,Y_pred_train)).round(3))
    test_error.append(np.sqrt(mean_squared_error(Y_test,Y_pred_test)).round(3))

print("Average trianing error",np.mean(training_error).round(2))
print("Average test error",np.mean(test_error).round(2))
print("Variance: ", (np.mean(test_error)-np.mean(training_error)).round(2))
# Out:
# Average trianing error 0.49
# Average test error 0.52
# Variance:  0.03

# %%
# Xtreme Gradient boosting Technique
from xgboost import XGBRegressor
XGB = XGBRegressor(gamma=20,reg_lambda=8,n_estimators=500,learning_rate=0.1)

# %%
training_error = []
test_error = []
Tr = []
Ts = []

# %%
# cross validation with XGBRegressor
import numpy as np
for i in range(1,101,1):
    X_train,X_test,Y_train,Y_test  = train_test_split(X,Y, test_size=0.30, random_state=i)
    XGB.fit(X_train,Y_train)
    Y_pred_train = XGB.predict(X_train)
    Y_pred_test = XGB.predict(X_test)
    training_error.append(np.sqrt(mean_squared_error(Y_train,Y_pred_train)).round(3))
    test_error.append(np.sqrt(mean_squared_error(Y_test,Y_pred_test)).round(3))

print("Average trianing error",np.mean(training_error).round(2))
print("Average test error",np.mean(test_error).round(2))
print("Variance: ", (np.mean(test_error)-np.mean(training_error)).round(2))
# Out:
# Average trianing error 0.5
# Average test error 0.5
# Variance:  0.0

# %%
# Compare the ouput with Gradient Boost, Ada Boost and XGBR

#Gradient Boost
#Average trianing error 0.36
#Average test error 0.53
#Variance:  0.17

# Ada Boost
#Average trianing error 0.49
#Average test error 0.52
#Variance:  0.03

# XGBR
#Average trianing error 0.5
#Average test error 0.5
#Variance:  0.0
